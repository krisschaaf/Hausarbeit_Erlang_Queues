# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [auf,hbq_Heap]]')
h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [auf,hbq_List]]')

h.plotMulti2D(lastN=2, type=5)
# type gibt an was interpoliert werden soll
# lastn wie viele dateien geplottet werden soll
# Out:
# pushDeliverReceive_auf_[hbq_Heap]215
# pushDeliverReceive_auf_[hbq_List]759

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushHBQonly, [real,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushHBQonly, [auf,hbq_List]]')
h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushHBQonly, [real,hbq_NotPatternMatched]]')

h.plotMulti2D(lastN=2, type=5)
# Out:
# pushHBQonly_real_[hbq_Heap]298
# pushHBQonly_real_[hbq_NotPatternMatched]876

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushHBQonly, [auf,hbq_Heap]]')
h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushHBQonly, [auf,hbq_List]]')
#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushHBQonly, [auf,hbq_NotPatternMatched]]')

h.plotMulti2D(lastN=2, type=5)
# Out:
# pushHBQonly_auf_[hbq_Heap]589
# pushHBQonly_auf_[hbq_List]276

# %%
import helper as h

#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushHBQonly, [real,hbq_Heap]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushHBQonly, [real,hbq_List]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushHBQonly, [auf,hbq_Heap]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushHBQonly, [auf,hbq_List]]')
h.plotMulti2D(lastN=4, type=5)
# Out:
# pushHBQonly_real_[hbq_Heap]835
# pushHBQonly_real_[hbq_List]976
# pushHBQonly_auf_[hbq_Heap]477
# pushHBQonly_auf_[hbq_List]468

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq_List]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq]]')

h.plotMulti2D(lastN=2, type=5)
# Out:
# pushDeliverReceive_rand_[hbq_List]526
# pushDeliverReceive_rand_[hbq_Heap]775

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq_Heap,10]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq_Heap,100]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq_List,10]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq_List,100]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_NotPatternMatched]]')
h.plotMulti2D(lastN=4, type=5)
# Out:
# pushDeliverReceive_rand_[hbq_Heap,10]833
# pushDeliverReceive_rand_[hbq_Heap,100]512
# pushDeliverReceive_rand_[hbq_List,10]914
# pushDeliverReceive_rand_[hbq_List,100]673

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_Heap,10]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_List,1]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_Heap,10]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_List,1]]')
h.plotMulti2D(lastN=4, type=5)
# Out:
# pushDeliverReceive_real_[hbq_Heap,10]439
# pushDeliverReceive_real_[hbq_List,1]867
# pushDeliverReceive_real_[hbq_Heap,10]618
# pushDeliverReceive_real_[hbq_List,1]759
