# %%
import helper as h

#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [auf,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [auf,hbq_List]]')

arrayA = ['comp/pushDeliverReceive_auf_[hbq_Heap]825.csv','comp/pushDeliverReceive_auf_[hbq_List]554.csv']
h.plotMulti2D(files=arrayA,lastN=2, type=5)
# type gibt an was interpoliert werden soll
# lastn wie viele dateien geplottet werden soll
# Out:
# pushDeliverReceive_auf_[hbq_Heap]825
# pushDeliverReceive_auf_[hbq_List]554

# %%
#import helper as h

#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [auf,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [auf,hbq_NotPatternMatched]]')

import helper as h

#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_List]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_NotPatternMatched]]')
filesA = ['comp/pushDeliverReceive_real_[hbq_NotPatternMatched]796.csv','comp/pushDeliverReceive_real_[hbq_Heap]867.csv','comp/pushDeliverReceive_real_[hbq_List]341.csv']
h.plotMulti2D(files=filesA,lastN=3, type=5)
# Out:
# pushDeliverReceive_real_[hbq_NotPatternMatched]796
# pushDeliverReceive_real_[hbq_Heap]867
# pushDeliverReceive_real_[hbq_List]341

# %%
import helper as h

#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_List]]')

arrayA = ['comp/pushDeliverReceive_real_[hbq_Heap]923.csv','comp/pushDeliverReceive_real_[hbq_List]839.csv']
h.plotMulti2D(files=arrayA,lastN=2, type=5)
# Out:
# pushDeliverReceive_real_[hbq_Heap]923
# pushDeliverReceive_real_[hbq_List]839

# %%
import helper as h

#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [rand,hbq_List]]')
#h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [rand,hbq_Heap]]')
#h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [rand,hbq]]')

arrayA = ['comp/pushDeliverReceive_rand_[hbq_List]526.csv','comp/pushDeliverReceive_rand_[hbq_Heap]775.csv']
h.plotMulti2D(files=arrayA,lastN=2, type=5)
# Out:
# pushDeliverReceive_rand_[hbq_List]526
# pushDeliverReceive_rand_[hbq_Heap]775

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_List]]')
h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_Heap]]')
h.runErlang('bench', 'markFull', '[100, 100, 250, hbqf, pushDeliverReceive, [real,hbq_NotPatternMatched]]')
h.plotMulti2D(lastN=3, type=5)
# Out:
# pushDeliverReceive_real_[hbq_List]560
# pushDeliverReceive_real_[hbq_Heap]404
# pushDeliverReceive_real_[hbq_NotPatternMatched]919

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_Heap,10]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_List,1]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_Heap,10]]')
h.runErlang('bench', 'markFull', '[100, 100, 100, hbqf, pushDeliverReceive, [real,hbq_List,1]]')
h.plotMulti2D(lastN=4, type=5)
# Out:
# pushDeliverReceive_real_[hbq_Heap,10]439
# pushDeliverReceive_real_[hbq_List,1]867
# pushDeliverReceive_real_[hbq_Heap,10]618
# pushDeliverReceive_real_[hbq_List,1]759

# %%
import helper as h

# h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,mydlq, 10]]')
# h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,dlq, 10]]')
h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,mydlq, 1]]')
h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,dlq, 1]]')
h.plotMulti2D(lastN=2, type=5)
# Out:
# pushDLQonly_auf_[mydlq,1]914
# pushDLQonly_auf_[dlq,1]557

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,mydlq]]')
h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,dlq]]')
h.plotMulti2D(lastN=2, type=5)

# %%
import helper as h

# h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,mydlq, 10]]')
# h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,dlq, 10]]')
# h.runErlang('bench', 'markFull', '[100, 100, 500, dlqf, pushDLQonly, [auf,dlq_haidar, 10]]')
# h.plotMulti2D(lastN=3, type=5)
# Out:
# pushDLQonly_auf_[mydlq,10]796
# pushDLQonly_auf_[dlq,10]162
# pushDLQonly_auf_[dlq_haidar,10]961

# %%
import helper as h

h.runErlang('bench', 'markFull', '[100, 100, 500, hbqf, pushHBQonlyStub, [real,myhbq, 1]]')
h.runErlang('bench', 'markFull', '[100, 100, 500, hbqf, pushHBQonlyStub, [real,myhbq, 10]]')
h.runErlang('bench', 'markFull', '[100, 100, 500, hbqf, pushHBQonlyStub, [real,hbq, 1]]')
h.runErlang('bench', 'markFull', '[100, 100, 500, hbqf, pushHBQonlyStub, [real,hbq, 10]]')
h.plotMulti2D(lastN=4, type=5)
# Out:
# pushHBQonlyStub_real_[myhbq,1]786
# pushHBQonlyStub_real_[myhbq,10]837
# pushHBQonlyStub_real_[hbq,1]749
# pushHBQonlyStub_real_[hbq,10]996
